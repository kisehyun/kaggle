# %%
import pandas as pd
import numpy as np
import gc
import warnings
warnings.filterwarnings('ignore')

# %%
def reduce_memory_usage(df, verbose=True):
    numerics = ["int8", "int16", "int32", "int64", "float16", "float32", "float64"]
    start_mem = df.memory_usage().sum() / 1024 ** 2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if (
                    c_min > np.finfo(np.float16).min
                    and c_max < np.finfo(np.float16).max
                ):
                    df[col] = df[col].astype(np.float16)
                elif (
                    c_min > np.finfo(np.float32).min
                    and c_max < np.finfo(np.float32).max
                ):
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024 ** 2
    if verbose:
        print(
            "Mem. usage decreased to {:.2f} Mb ({:.1f}% reduction)".format(
                end_mem, 100 * (start_mem - end_mem) / start_mem
            )
        )
    return df

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train = reduce_memory_usage(train)
test = reduce_memory_usage(test)
# Out:
# Mem. usage decreased to 505.45 Mb (76.9% reduction)
# Mem. usage decreased to 252.25 Mb (76.9% reduction)

# %%
train.to_csv("train.csv", index = False)
test.to_csv("test.csv", index = False)

# %%
cor = train.corr()['target']

# %%
col_nunique = [train[c].nunique() for c in train.columns[:-1]]
col_n_df = pd.DataFrame({'column' : train.columns[:-1], 'nunique' : col_nunique})

# %%
col_n_df[col_n_df['nunique'] < 3]
# Out:
#     column  nunique
# 23     f22        2
# 44     f43        2
# 243   f242        2
# 244   f243        2
# 245   f244        2
# 246   f245        2
# 247   f246        2
# 248   f247        2
# 249   f248        2
# 250   f249        2
# 251   f250        2
# 252   f251        2
# 253   f252        2
# 254   f253        2
# 255   f254        2
# 256   f255        2
# 257   f256        2
# 258   f257        2
# 259   f258        2
# 260   f259        2
# 261   f260        2
# 262   f261        2
# 263   f262        2
# 264   f263        2
# 265   f264        2
# 266   f265        2
# 267   f266        2
# 268   f267        2
# 269   f268        2
# 270   f269        2
# 271   f270        2
# 272   f271        2
# 273   f272        2
# 274   f273        2
# 275   f274        2
# 276   f275        2
# 277   f276        2
# 278   f277        2
# 279   f278        2
# 280   f279        2
# 281   f280        2
# 282   f281        2
# 283   f282        2
# 284   f283        2
# 285   f284        2

# %%
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
X = train.iloc[:, 1:-1]
y = train.target

# %%
target = test.iloc[:, 1:]

# %%
del train
del test

# %%
X['std'] = X.std(axis=1)
X['min'] = X.min(axis=1)
X['max'] = X.max(axis=1)

target['std'] = target.std(axis=1)
target['min'] = target.min(axis=1)
target['max'] = target.max(axis=1)

# %%
skew_df = pd.DataFrame({'before' : X.skew(), 'after' : np.log1p(X).skew()})

# %%
skew_df
# Out:
#         before     after
# f0    2.747791  2.310211
# f1    0.293400  0.103153
# f2    1.345657  1.016755
# f3    1.612213  1.332803
# f4    0.381527  0.171789
# ...        ...       ...
# f280  2.084497  2.084497
# f281  1.505239  1.505239
# f282  1.895395  1.895395
# f283  1.633264  1.633264
# f284  1.909962  1.909962
#
# [285 rows x 2 columns]

# %%
skew_df['gap'] = skew_df.before.abs() - skew_df.after.abs()

# %%
l_t_cols = skew_df[skew_df.gap > 0.5].index

# %%
X[l_t_cols] = np.log1p(X[l_t_cols])

# %%
target[l_t_cols] = np.log1p(target[l_t_cols])

# %%
scaler = StandardScaler()

# %%
X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)

# %%
target = pd.DataFrame(scaler.transform(target), columns = X.columns)

# %%
skf = StratifiedKFold(n_splits = 10, random_state = 42, shuffle = True)

# %%
cb = CatBoostClassifier(iterations = 10000, learning_rate = .03, random_state = 42)

# %%
cb_pred = np.zeros((target.shape[0]))
for i, idx in enumerate(zip(skf.split(X, y))) :
    tr_x, tr_y = X.iloc[idx[0][0]], y.iloc[idx[0][0]]
    val_x, val_y = X.iloc[idx[0][1]], y.iloc[idx[0][1]]
    
    cb.fit(tr_x, tr_y, eval_set = [(tr_x, tr_y), (val_x, val_y)], verbose = 1000, early_stopping_rounds = 500)
    
    val_pred = cb.predict_proba(val_x)[:, 1]
    
    score = roc_auc_score(val_y, val_pred)
    
    print(f'{i + 1} Fold roc_auc_score = {score}')
    
    fold_pred = cb.predict_proba(target)[:, 1]
    cb_pred += (fold_pred / 10)
# Out:
# 0:	learn: 0.6729574	test: 0.6729834	test1: 0.6725985	best: 0.6725985 (0)	total: 241ms	remaining: 40m 9s
# 1000:	learn: 0.4617345	test: 0.4617604	test1: 0.4630342	best: 0.4630342 (1000)	total: 1m 57s	remaining: 17m 40s
# 2000:	learn: 0.4508551	test: 0.4508816	test1: 0.4614514	best: 0.4614514 (2000)	total: 3m 49s	remaining: 15m 15s
# 3000:	learn: 0.4415388	test: 0.4415654	test1: 0.4612090	best: 0.4612069 (2973)	total: 5m 38s	remaining: 13m 8s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4611877686
# bestIteration = 3383
#
# Shrink model to first 3384 iterations.
# 1 Fold roc_auc_score = 0.8603574762873203
# 0:	learn: 0.6728715	test: 0.6728744	test1: 0.6728713	best: 0.6728713 (0)	total: 160ms	remaining: 26m 39s
# 1000:	learn: 0.4611462	test: 0.4611724	test1: 0.4683039	best: 0.4683037 (999)	total: 1m 58s	remaining: 17m 47s
# 2000:	learn: 0.4502705	test: 0.4502974	test1: 0.4667932	best: 0.4667760 (1974)	total: 3m 50s	remaining: 15m 22s
# 3000:	learn: 0.4409600	test: 0.4409869	test1: 0.4666000	best: 0.4665913 (2985)	total: 5m 40s	remaining: 13m 14s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4665913256
# bestIteration = 2985
#
# Shrink model to first 2986 iterations.
# 2 Fold roc_auc_score = 0.8562469183395404
# 0:	learn: 0.6728148	test: 0.6728548	test1: 0.6729775	best: 0.6729775 (0)	total: 200ms	remaining: 33m 24s
# 1000:	learn: 0.4608817	test: 0.4609081	test1: 0.4709201	best: 0.4709201 (1000)	total: 1m 55s	remaining: 17m 18s
# 2000:	learn: 0.4500212	test: 0.4500477	test1: 0.4691996	best: 0.4691978 (1998)	total: 3m 45s	remaining: 14m 59s
# 3000:	learn: 0.4406993	test: 0.4407263	test1: 0.4690261	best: 0.4689722 (2581)	total: 5m 46s	remaining: 13m 28s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4689721568
# bestIteration = 2581
#
# Shrink model to first 2582 iterations.
# 3 Fold roc_auc_score = 0.8546857668402106
# 0:	learn: 0.6728292	test: 0.6728432	test1: 0.6729863	best: 0.6729863 (0)	total: 150ms	remaining: 25m 1s
# 1000:	learn: 0.4610274	test: 0.4610539	test1: 0.4691244	best: 0.4691236 (999)	total: 1m 57s	remaining: 17m 38s
# 2000:	learn: 0.4501925	test: 0.4502191	test1: 0.4674940	best: 0.4674857 (1995)	total: 3m 48s	remaining: 15m 12s
# 3000:	learn: 0.4409503	test: 0.4409774	test1: 0.4672795	best: 0.4672642 (2974)	total: 5m 39s	remaining: 13m 11s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4672473752
# bestIteration = 3401
#
# Shrink model to first 3402 iterations.
# 4 Fold roc_auc_score = 0.8558833927904104
# 0:	learn: 0.6729407	test: 0.6729523	test1: 0.6730181	best: 0.6730181 (0)	total: 156ms	remaining: 25m 59s
# 1000:	learn: 0.4611110	test: 0.4611375	test1: 0.4691145	best: 0.4691145 (1000)	total: 1m 58s	remaining: 17m 47s
# 2000:	learn: 0.4502458	test: 0.4502724	test1: 0.4674681	best: 0.4674473 (1943)	total: 3m 58s	remaining: 15m 53s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4673670078
# bestIteration = 2351
#
# Shrink model to first 2352 iterations.
# 5 Fold roc_auc_score = 0.8558121083219488
# 0:	learn: 0.6729335	test: 0.6729607	test1: 0.6729495	best: 0.6729495 (0)	total: 161ms	remaining: 26m 46s
# 1000:	learn: 0.4614795	test: 0.4615053	test1: 0.4660088	best: 0.4660088 (1000)	total: 1m 58s	remaining: 17m 45s
# 2000:	learn: 0.4506420	test: 0.4506687	test1: 0.4641427	best: 0.4641325 (1989)	total: 3m 50s	remaining: 15m 20s
# 3000:	learn: 0.4413436	test: 0.4413704	test1: 0.4638461	best: 0.4638461 (3000)	total: 5m 40s	remaining: 13m 13s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4637976963
# bestIteration = 3304
#
# Shrink model to first 3305 iterations.
# 6 Fold roc_auc_score = 0.8584561735532096
# 0:	learn: 0.6728554	test: 0.6728636	test1: 0.6729833	best: 0.6729833 (0)	total: 154ms	remaining: 25m 41s
# 1000:	learn: 0.4609864	test: 0.4610126	test1: 0.4696426	best: 0.4696426 (1000)	total: 2m 1s	remaining: 18m 12s
# 2000:	learn: 0.4501075	test: 0.4501341	test1: 0.4683670	best: 0.4683604 (1991)	total: 3m 55s	remaining: 15m 40s
# 3000:	learn: 0.4407484	test: 0.4407751	test1: 0.4682928	best: 0.4682825 (2984)	total: 5m 44s	remaining: 13m 23s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4682800632
# bestIteration = 3051
#
# Shrink model to first 3052 iterations.
# 7 Fold roc_auc_score = 0.8552711690179093
# 0:	learn: 0.6728318	test: 0.6728764	test1: 0.6729025	best: 0.6729025 (0)	total: 150ms	remaining: 24m 56s
# 1000:	learn: 0.4610649	test: 0.4610912	test1: 0.4693367	best: 0.4693367 (1000)	total: 1m 59s	remaining: 17m 54s
# 2000:	learn: 0.4502173	test: 0.4502441	test1: 0.4676727	best: 0.4676607 (1923)	total: 3m 54s	remaining: 15m 37s
# 3000:	learn: 0.4409718	test: 0.4409988	test1: 0.4674589	best: 0.4673850 (2765)	total: 5m 44s	remaining: 13m 24s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4673850281
# bestIteration = 2765
#
# Shrink model to first 2766 iterations.
# 8 Fold roc_auc_score = 0.8558464163480572
# 0:	learn: 0.6728341	test: 0.6728422	test1: 0.6729067	best: 0.6729067 (0)	total: 148ms	remaining: 24m 36s
# 1000:	learn: 0.4611007	test: 0.4611270	test1: 0.4689756	best: 0.4689756 (1000)	total: 1m 57s	remaining: 17m 38s
# 2000:	learn: 0.4501976	test: 0.4502244	test1: 0.4674876	best: 0.4674840 (1996)	total: 3m 48s	remaining: 15m 13s
# 3000:	learn: 0.4408991	test: 0.4409261	test1: 0.4673725	best: 0.4673220 (2773)	total: 5m 36s	remaining: 13m 5s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4673220036
# bestIteration = 2773
#
# Shrink model to first 2774 iterations.
# 9 Fold roc_auc_score = 0.8560103896991751
# 0:	learn: 0.6728555	test: 0.6728685	test1: 0.6728770	best: 0.6728770 (0)	total: 156ms	remaining: 26m
# 1000:	learn: 0.4612095	test: 0.4612357	test1: 0.4678197	best: 0.4678197 (1000)	total: 1m 58s	remaining: 17m 45s
# 2000:	learn: 0.4503250	test: 0.4503519	test1: 0.4662293	best: 0.4662130 (1961)	total: 3m 51s	remaining: 15m 23s
# 3000:	learn: 0.4410107	test: 0.4410377	test1: 0.4660171	best: 0.4660046 (2800)	total: 5m 42s	remaining: 13m 19s
# Stopped by overfitting detector  (500 iterations wait)
#
# bestTest = 0.4659721749
# bestIteration = 3293
#
# Shrink model to first 3294 iterations.
# 10 Fold roc_auc_score = 0.8566198214608274

# %%
skf = StratifiedKFold(n_splits = 5, random_state = 42, shuffle = True)

# %%
params = {
    'max_depth': 6,
    'subsample': 0.7,
    'colsample_bytree': 0.2,
    'colsample_bylevel': 0.6000000000000001,
    'min_child_weight': 56.41980735551558,
    'reg_lambda': 75.56651890088857,
    'reg_alpha': 0.11766857055687065,
    'gamma': 0.6407823221122686,
    'booster': 'gbtree',
    'eval_metric': 'auc',
    'use_label_encoder': False
    }

# %%
xgb = XGBClassifier(random_state = 42, n_estimators = 10000, learning_rate = .03, **params)

# %%
xgb_pred = np.zeros((target.shape[0]))
for i, idx in enumerate(zip(skf.split(X, y))) :
    tr_x, tr_y = X.iloc[idx[0][0]], y.iloc[idx[0][0]]
    val_x, val_y = X.iloc[idx[0][1]], y.iloc[idx[0][1]]
    
    xgb.fit(tr_x, tr_y, eval_set = [(tr_x, tr_y), (val_x, val_y)], verbose = 1000, early_stopping_rounds = 500)
    
    val_pred = xgb.predict_proba(np.float32(val_x))[:, 1]
    
    score = roc_auc_score(val_y, val_pred)
    
    print(f'{i + 1} Fold roc_auc_score = {score}')
    
    fold_pred = xgb.predict_proba(np.float32(target))[:, 1]
    xgb_pred += (fold_pred / 5)
# Out:
# [0]	validation_0-auc:0.78912	validation_1-auc:0.79223
# [1000]	validation_0-auc:0.86738	validation_1-auc:0.85749
# [2000]	validation_0-auc:0.87736	validation_1-auc:0.85848
# [3000]	validation_0-auc:0.88439	validation_1-auc:0.85845
# [3029]	validation_0-auc:0.88457	validation_1-auc:0.85844
# 1 Fold roc_auc_score = 0.858575467033657
# [0]	validation_0-auc:0.78975	validation_1-auc:0.78805
# [1000]	validation_0-auc:0.86801	validation_1-auc:0.85421
# [2000]	validation_0-auc:0.87787	validation_1-auc:0.85563
# [2794]	validation_0-auc:0.88339	validation_1-auc:0.85567
# 2 Fold roc_auc_score = 0.8557973935697676
# [0]	validation_0-auc:0.78931	validation_1-auc:0.78849
# [1000]	validation_0-auc:0.86760	validation_1-auc:0.85613
# [2000]	validation_0-auc:0.87753	validation_1-auc:0.85745
# [3000]	validation_0-auc:0.88439	validation_1-auc:0.85740
# [3238]	validation_0-auc:0.88588	validation_1-auc:0.85734
# 3 Fold roc_auc_score = 0.8575134835844367
# [0]	validation_0-auc:0.79001	validation_1-auc:0.78815
# [1000]	validation_0-auc:0.86801	validation_1-auc:0.85486
# [2000]	validation_0-auc:0.87806	validation_1-auc:0.85594
# [3000]	validation_0-auc:0.88507	validation_1-auc:0.85593
# [3032]	validation_0-auc:0.88530	validation_1-auc:0.85593
# 4 Fold roc_auc_score = 0.8560432499010939
# [0]	validation_0-auc:0.78959	validation_1-auc:0.78824
# [1000]	validation_0-auc:0.86778	validation_1-auc:0.85564
# [2000]	validation_0-auc:0.87775	validation_1-auc:0.85675
# [2636]	validation_0-auc:0.88235	validation_1-auc:0.85671
# 5 Fold roc_auc_score = 0.8568025377155077

# %%
tr_x.dtypes
# Out:
# f0      float16
# f1      float16
# f2      float16
# f3      float16
# f4      float16
#          ...
# f283       int8
# f284       int8
# std     float16
# min     float16
# max     float16
# Length: 288, dtype: object

# %%
lgbm = LGBMClassifier(random_state = 42, n_estimators = 10000, learning_rate = .05, max_depth = 5)

# %%
lgbm_pred = np.zeros((target.shape[0]))
for i, idx in enumerate(zip(skf.split(X, y))) :
    tr_x, tr_y = X.iloc[idx[0][0]], y.iloc[idx[0][0]]
    val_x, val_y = X.iloc[idx[0][1]], y.iloc[idx[0][1]]
    
    lgbm.fit(tr_x, tr_y, eval_set = [(tr_x, tr_y), (val_x, val_y)], verbose = 1000, early_stopping_rounds = 500)
    
    val_pred = lgbm.predict_proba(val_x)[:, 1]
    
    score = roc_auc_score(val_y, val_pred)
    
    print(f'{i + 1} Fold roc_auc_score = {score}\n')
    
    fold_pred = lgbm.predict_proba(target)[:, 1]
    lgbm_pred += (fold_pred / 10)
# Out:
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.445615	valid_1's binary_logloss: 0.462774
# Early stopping, best iteration is:
# [1494]	training's binary_logloss: 0.434989	valid_1's binary_logloss: 0.462077
# 1 Fold roc_auc_score = 0.8598921930404622
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.445082	valid_1's binary_logloss: 0.467997
# [2000]	training's binary_logloss: 0.424939	valid_1's binary_logloss: 0.467494
# Early stopping, best iteration is:
# [1614]	training's binary_logloss: 0.432123	valid_1's binary_logloss: 0.467369
# 2 Fold roc_auc_score = 0.8557803574914553
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.444877	valid_1's binary_logloss: 0.470752
# [2000]	training's binary_logloss: 0.424683	valid_1's binary_logloss: 0.469893
# Early stopping, best iteration is:
# [1612]	training's binary_logloss: 0.431895	valid_1's binary_logloss: 0.469733
# 3 Fold roc_auc_score = 0.8541626479378072
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.445103	valid_1's binary_logloss: 0.468639
# [2000]	training's binary_logloss: 0.42487	valid_1's binary_logloss: 0.46785
# Early stopping, best iteration is:
# [2011]	training's binary_logloss: 0.424676	valid_1's binary_logloss: 0.467845
# 4 Fold roc_auc_score = 0.8555121632338816
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.44509	valid_1's binary_logloss: 0.468447
# Early stopping, best iteration is:
# [1343]	training's binary_logloss: 0.43746	valid_1's binary_logloss: 0.467954
# 5 Fold roc_auc_score = 0.8554164407419497
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.445482	valid_1's binary_logloss: 0.465392
# [2000]	training's binary_logloss: 0.425288	valid_1's binary_logloss: 0.464417
# Early stopping, best iteration is:
# [1950]	training's binary_logloss: 0.426193	valid_1's binary_logloss: 0.464391
# 6 Fold roc_auc_score = 0.858036260766218
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.444932	valid_1's binary_logloss: 0.469676
# [2000]	training's binary_logloss: 0.424654	valid_1's binary_logloss: 0.469483
# Early stopping, best iteration is:
# [1717]	training's binary_logloss: 0.429891	valid_1's binary_logloss: 0.469259
# 7 Fold roc_auc_score = 0.8546830628759108
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.444991	valid_1's binary_logloss: 0.468814
# [2000]	training's binary_logloss: 0.424755	valid_1's binary_logloss: 0.468293
# Early stopping, best iteration is:
# [1512]	training's binary_logloss: 0.433962	valid_1's binary_logloss: 0.468158
# 8 Fold roc_auc_score = 0.8554367887705445
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.445015	valid_1's binary_logloss: 0.46891
# [2000]	training's binary_logloss: 0.424814	valid_1's binary_logloss: 0.468458
# Early stopping, best iteration is:
# [1554]	training's binary_logloss: 0.433226	valid_1's binary_logloss: 0.46826
# 9 Fold roc_auc_score = 0.8554092331451493
#
# Training until validation scores don't improve for 500 rounds
# [1000]	training's binary_logloss: 0.445135	valid_1's binary_logloss: 0.467713
# [2000]	training's binary_logloss: 0.42482	valid_1's binary_logloss: 0.467096
# Early stopping, best iteration is:
# [1597]	training's binary_logloss: 0.432387	valid_1's binary_logloss: 0.466958
# 10 Fold roc_auc_score = 0.8560486461344323

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
submission['target'] = lgbm_pred * .5 + xgb_pred * .5

# %%
submission.to_csv("1012_1st.csv", index = False)
