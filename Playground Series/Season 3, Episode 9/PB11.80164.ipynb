# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/My Drive/kaggle/session3episode9/
# Out:
# /content/gdrive/My Drive/kaggle/session3episode9

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# !pip install catboost
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.15.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.3.5)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.10.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.5.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.5.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)
# Installing collected packages: catboost
# Successfully installed catboost-1.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 7.7 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.4.46)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.65.0)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 19.9 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (6.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.2 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.0

# %%
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import optuna
from optuna import Trial, visualization
from optuna.samplers import TPESampler

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters = 8, random_state = 42)

# %%
train['km_cls'] = km.fit_predict(train.iloc[:, 1:-1])
test['km_cls'] = km.predict(test.iloc[:, 1:])

# %%
train['feature_mean'] = train.iloc[:, 1:-2].sum(axis = 1)
test['feature_mean'] = test.iloc[:, 1:-1].sum(axis = 1)

# %%
kf = KFold(n_splits = 10, random_state = 42, shuffle = True)

# %%
X = train.drop(['id', 'Strength'], axis = 1)
y = train['Strength']
target = test[X.columns]

# %%
def RMSE(y_actual, y_pred):
    score = mean_squared_error(y_actual, y_pred, squared = False)
    return score

# %%
def LGBM_objective(trial : Trial, X, y) :
    
    param = {
        "objective": trial.suggest_categorical("objective", ['regression']),
        "metric": trial.suggest_categorical("metric", ['rmse']), # 'rmse'
        "verbose": trial.suggest_categorical("verbose", [0]),
        "random_state": trial.suggest_categorical("random_state", [42]),
        "n_estimators": trial.suggest_int("n_estimators", 5000, 15000),
        "learning_rate": trial.suggest_discrete_uniform('learning_rate',0.005, 0.05, 0.001),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1, 0.1),
        'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1, 0.1),
        'num_leaves' : trial.suggest_int('num_leaves', 2, 256),
    }
    
    lgbm_rmse = 0
    
    for i, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
        tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
        val_x, val_y = X.iloc[val_idx], y.iloc[val_idx]

        lgbm = LGBMRegressor(**param)
        lgbm.fit(tr_x, tr_y, eval_set = [(tr_x, tr_y), (val_x, val_y)], early_stopping_rounds = 1500, verbose = 0)

        val_pred = lgbm.predict(val_x)
        fold_rmse = mean_squared_error(val_y, val_pred) ** 0.5
        lgbm_rmse += fold_rmse / kf.n_splits
    return lgbm_rmse

# %%
study = optuna.create_study(direction = 'minimize', sampler = TPESampler())
# Out:
# [I 2023-03-13 11:54:43,301] A new study created in memory with name: no-name-1076d388-8cb9-4db0-852f-37b20d450c37

# %%
study.optimize(lambda trial : LGBM_objective(trial, X, y), n_trials = 30)
# Out:
# [I 2023-03-13 11:55:49,465] Trial 0 finished with value: 12.310675684964748 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 9775, 'learning_rate': 0.026000000000000002, 'max_depth': 8, 'min_child_samples': 8, 'subsample': 0.6, 'colsample_bytree': 1.0, 'num_leaves': 136}. Best is trial 0 with value: 12.310675684964748.
# [I 2023-03-13 11:56:15,481] Trial 1 finished with value: 12.106671479578688 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 6209, 'learning_rate': 0.024, 'max_depth': 4, 'min_child_samples': 36, 'subsample': 0.6, 'colsample_bytree': 1.0, 'num_leaves': 248}. Best is trial 1 with value: 12.106671479578688.
# [I 2023-03-13 11:56:52,015] Trial 2 finished with value: 12.148022696267653 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 9712, 'learning_rate': 0.019, 'max_depth': 9, 'min_child_samples': 63, 'subsample': 1.0, 'colsample_bytree': 0.7, 'num_leaves': 79}. Best is trial 1 with value: 12.106671479578688.
# [I 2023-03-13 11:57:35,046] Trial 3 finished with value: 12.135540541515583 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 6844, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_samples': 62, 'subsample': 0.6, 'colsample_bytree': 0.9, 'num_leaves': 176}. Best is trial 1 with value: 12.106671479578688.
# [I 2023-03-13 11:57:59,748] Trial 4 finished with value: 12.111520896762126 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 5096, 'learning_rate': 0.038, 'max_depth': 8, 'min_child_samples': 54, 'subsample': 0.8, 'colsample_bytree': 0.6, 'num_leaves': 25}. Best is trial 1 with value: 12.106671479578688.
# [I 2023-03-13 11:58:29,047] Trial 5 finished with value: 12.124040651287963 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 9318, 'learning_rate': 0.016, 'max_depth': 6, 'min_child_samples': 53, 'subsample': 0.9, 'colsample_bytree': 0.8, 'num_leaves': 130}. Best is trial 1 with value: 12.106671479578688.
# [I 2023-03-13 11:58:50,438] Trial 6 finished with value: 12.116081099130799 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 5471, 'learning_rate': 0.036, 'max_depth': 6, 'min_child_samples': 61, 'subsample': 0.9, 'colsample_bytree': 0.5, 'num_leaves': 162}. Best is trial 1 with value: 12.106671479578688.
# [I 2023-03-13 11:59:24,332] Trial 7 finished with value: 12.091560459844006 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 8122, 'learning_rate': 0.014000000000000002, 'max_depth': 7, 'min_child_samples': 93, 'subsample': 0.6, 'colsample_bytree': 1.0, 'num_leaves': 121}. Best is trial 7 with value: 12.091560459844006.
# [I 2023-03-13 11:59:58,442] Trial 8 finished with value: 12.134790389551627 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 6666, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_samples': 100, 'subsample': 0.8, 'colsample_bytree': 0.5, 'num_leaves': 141}. Best is trial 7 with value: 12.091560459844006.
# [I 2023-03-13 12:00:23,737] Trial 9 finished with value: 12.115378176114142 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 14924, 'learning_rate': 0.031000000000000003, 'max_depth': 5, 'min_child_samples': 57, 'subsample': 0.9, 'colsample_bytree': 0.9, 'num_leaves': 45}. Best is trial 7 with value: 12.091560459844006.
# [I 2023-03-13 12:00:45,710] Trial 10 finished with value: 12.096064827041687 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 12716, 'learning_rate': 0.047, 'max_depth': 3, 'min_child_samples': 96, 'subsample': 0.5, 'colsample_bytree': 0.8, 'num_leaves': 219}. Best is trial 7 with value: 12.091560459844006.
# [I 2023-03-13 12:01:04,000] Trial 11 finished with value: 12.089129923881584 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 12959, 'learning_rate': 0.049999999999999996, 'max_depth': 3, 'min_child_samples': 98, 'subsample': 0.5, 'colsample_bytree': 0.8, 'num_leaves': 224}. Best is trial 11 with value: 12.089129923881584.
# [I 2023-03-13 12:01:22,315] Trial 12 finished with value: 12.091230207199073 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 12147, 'learning_rate': 0.046, 'max_depth': 3, 'min_child_samples': 79, 'subsample': 0.5, 'colsample_bytree': 0.7, 'num_leaves': 86}. Best is trial 11 with value: 12.089129923881584.
# [I 2023-03-13 12:01:42,760] Trial 13 finished with value: 12.094629482445514 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 12142, 'learning_rate': 0.048, 'max_depth': 3, 'min_child_samples': 79, 'subsample': 0.5, 'colsample_bytree': 0.7, 'num_leaves': 85}. Best is trial 11 with value: 12.089129923881584.
# [I 2023-03-13 12:02:01,858] Trial 14 finished with value: 12.08145174777904 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 12098, 'learning_rate': 0.041, 'max_depth': 4, 'min_child_samples': 81, 'subsample': 0.5, 'colsample_bytree': 0.6, 'num_leaves': 208}. Best is trial 14 with value: 12.08145174777904.
# [I 2023-03-13 12:02:25,183] Trial 15 finished with value: 12.09456703860588 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 13570, 'learning_rate': 0.041999999999999996, 'max_depth': 5, 'min_child_samples': 81, 'subsample': 0.7, 'colsample_bytree': 0.6, 'num_leaves': 210}. Best is trial 14 with value: 12.08145174777904.
# [I 2023-03-13 12:02:44,150] Trial 16 finished with value: 12.091624759061032 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 11213, 'learning_rate': 0.049999999999999996, 'max_depth': 4, 'min_child_samples': 36, 'subsample': 0.7, 'colsample_bytree': 0.6, 'num_leaves': 251}. Best is trial 14 with value: 12.08145174777904.
# [I 2023-03-13 12:03:10,044] Trial 17 finished with value: 12.094989948044617 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 14372, 'learning_rate': 0.04, 'max_depth': 4, 'min_child_samples': 85, 'subsample': 0.5, 'colsample_bytree': 0.8, 'num_leaves': 197}. Best is trial 14 with value: 12.08145174777904.
# [I 2023-03-13 12:03:35,575] Trial 18 finished with value: 12.119010821899778 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 10967, 'learning_rate': 0.034, 'max_depth': 5, 'min_child_samples': 69, 'subsample': 0.7, 'colsample_bytree': 0.9, 'num_leaves': 230}. Best is trial 14 with value: 12.08145174777904.
# [I 2023-03-13 12:03:54,632] Trial 19 finished with value: 12.080150285883681 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 13345, 'learning_rate': 0.044, 'max_depth': 4, 'min_child_samples': 89, 'subsample': 0.5, 'colsample_bytree': 0.6, 'num_leaves': 181}. Best is trial 19 with value: 12.080150285883681.
# [I 2023-03-13 12:04:19,283] Trial 20 finished with value: 12.11540899372294 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 11042, 'learning_rate': 0.030000000000000002, 'max_depth': 5, 'min_child_samples': 38, 'subsample': 0.6, 'colsample_bytree': 0.5, 'num_leaves': 182}. Best is trial 19 with value: 12.080150285883681.
# [I 2023-03-13 12:04:41,637] Trial 21 finished with value: 12.079266933571896 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 13336, 'learning_rate': 0.043, 'max_depth': 4, 'min_child_samples': 89, 'subsample': 0.5, 'colsample_bytree': 0.6, 'num_leaves': 200}. Best is trial 21 with value: 12.079266933571896.
# [I 2023-03-13 12:05:00,745] Trial 22 finished with value: 12.082119006585943 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 13812, 'learning_rate': 0.041999999999999996, 'max_depth': 4, 'min_child_samples': 88, 'subsample': 0.5, 'colsample_bytree': 0.6, 'num_leaves': 161}. Best is trial 21 with value: 12.079266933571896.
# [I 2023-03-13 12:05:25,667] Trial 23 finished with value: 12.127108381443048 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 11796, 'learning_rate': 0.044, 'max_depth': 6, 'min_child_samples': 71, 'subsample': 0.6, 'colsample_bytree': 0.6, 'num_leaves': 196}. Best is trial 21 with value: 12.079266933571896.
# [I 2023-03-13 12:05:45,256] Trial 24 finished with value: 12.087754747399472 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 13155, 'learning_rate': 0.034, 'max_depth': 4, 'min_child_samples': 73, 'subsample': 0.5, 'colsample_bytree': 0.5, 'num_leaves': 197}. Best is trial 21 with value: 12.079266933571896.
# [I 2023-03-13 12:06:25,477] Trial 25 finished with value: 12.104662530140624 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 14377, 'learning_rate': 0.039, 'max_depth': 5, 'min_child_samples': 91, 'subsample': 0.5, 'colsample_bytree': 0.7, 'num_leaves': 155}. Best is trial 21 with value: 12.079266933571896.
# [I 2023-03-13 12:06:47,138] Trial 26 finished with value: 12.07826530495262 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 12476, 'learning_rate': 0.044, 'max_depth': 4, 'min_child_samples': 86, 'subsample': 0.6, 'colsample_bytree': 0.6, 'num_leaves': 104}. Best is trial 26 with value: 12.07826530495262.
# [I 2023-03-13 12:07:34,368] Trial 27 finished with value: 12.1516282713963 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 13570, 'learning_rate': 0.005, 'max_depth': 7, 'min_child_samples': 45, 'subsample': 0.6, 'colsample_bytree': 0.5, 'num_leaves': 110}. Best is trial 26 with value: 12.07826530495262.
# [I 2023-03-13 12:07:55,994] Trial 28 finished with value: 12.099617815266155 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 10579, 'learning_rate': 0.045, 'max_depth': 3, 'min_child_samples': 22, 'subsample': 0.7, 'colsample_bytree': 0.7, 'num_leaves': 104}. Best is trial 26 with value: 12.07826530495262.
# [I 2023-03-13 12:08:25,150] Trial 29 finished with value: 12.180204445991533 and parameters: {'objective': 'regression', 'metric': 'rmse', 'verbose': 0, 'random_state': 42, 'n_estimators': 14927, 'learning_rate': 0.025, 'max_depth': 6, 'min_child_samples': 10, 'subsample': 0.6, 'colsample_bytree': 0.6, 'num_leaves': 64}. Best is trial 26 with value: 12.07826530495262.

# %%
lgbm_params = study.best_params

# %%
lgbm_params
# Out:
# {'objective': 'regression',
#  'metric': 'rmse',
#  'verbose': 0,
#  'random_state': 42,
#  'n_estimators': 12476,
#  'learning_rate': 0.044,
#  'max_depth': 4,
#  'min_child_samples': 86,
#  'subsample': 0.6,
#  'colsample_bytree': 0.6,
#  'num_leaves': 104}

# %%
def XGB_objective(trial : Trial, X, y) :
    
    param = {
        "objective": trial.suggest_categorical("objective", ['reg:squarederror']),
        "random_state": trial.suggest_categorical("random_state", [42]),
        "n_estimators": trial.suggest_int("n_estimators", 5000, 15000),
        "learning_rate": trial.suggest_discrete_uniform('learning_rate',0.005, 0.05, 0.001),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1, 0.1),
        'colsample_bytree': trial.suggest_discrete_uniform('colsample_bytree', 0.5, 1, 0.1),
        'lambda' : trial.suggest_loguniform('lambda', 1e-3, 5.),
        'alpha' : trial.suggest_loguniform('alpha', 1e-3, 5)
    }
    
    XGB_rmse = 0
    
    for i, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
        tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
        val_x, val_y = X.iloc[val_idx], y.iloc[val_idx]

        model = XGBRegressor(**param)
        model.fit(tr_x, tr_y, eval_set = [(tr_x, tr_y), (val_x, val_y)], early_stopping_rounds = 1500, verbose = 0)

        val_pred = model.predict(val_x)
        fold_rmse = mean_squared_error(val_y, val_pred) ** 0.5
        XGB_rmse += fold_rmse / kf.n_splits
    return XGB_rmse

# %%
study = optuna.create_study(direction = 'minimize', sampler = TPESampler())
# Out:
# [I 2023-03-13 12:08:26,762] A new study created in memory with name: no-name-49ae5396-13a9-4a7c-afc6-5b0e7f295612

# %%
study.optimize(lambda trial : XGB_objective(trial, X, y), n_trials = 20)
# Out:
# [I 2023-03-13 12:09:46,773] Trial 0 finished with value: 12.118257333224019 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 6685, 'learning_rate': 0.011, 'max_depth': 4, 'subsample': 1.0, 'colsample_bytree': 0.7, 'lambda': 0.15139542532579275, 'alpha': 1.071093684134274}. Best is trial 0 with value: 12.118257333224019.
# [I 2023-03-13 12:11:44,043] Trial 1 finished with value: 12.33208556368551 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 9520, 'learning_rate': 0.041999999999999996, 'max_depth': 8, 'subsample': 0.5, 'colsample_bytree': 0.6, 'lambda': 0.40110913238254914, 'alpha': 0.03311319824431492}. Best is trial 0 with value: 12.118257333224019.
# [I 2023-03-13 12:13:04,317] Trial 2 finished with value: 12.062863787354804 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 10783, 'learning_rate': 0.027, 'max_depth': 4, 'subsample': 0.5, 'colsample_bytree': 0.9, 'lambda': 4.852787778924969, 'alpha': 0.0020661541857410603}. Best is trial 2 with value: 12.062863787354804.
# [I 2023-03-13 12:15:44,781] Trial 3 finished with value: 12.499960157270689 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 6635, 'learning_rate': 0.034999999999999996, 'max_depth': 9, 'subsample': 0.9, 'colsample_bytree': 0.8, 'lambda': 0.02486889485773247, 'alpha': 1.084237536460917}. Best is trial 2 with value: 12.062863787354804.
# [I 2023-03-13 12:16:37,300] Trial 4 finished with value: 12.057041511757687 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 10210, 'learning_rate': 0.037, 'max_depth': 3, 'subsample': 0.5, 'colsample_bytree': 0.5, 'lambda': 2.242478851143795, 'alpha': 0.0019456413022481429}. Best is trial 4 with value: 12.057041511757687.
# [I 2023-03-13 12:17:37,880] Trial 5 finished with value: 12.142933847167104 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 13338, 'learning_rate': 0.038, 'max_depth': 5, 'subsample': 1.0, 'colsample_bytree': 0.5, 'lambda': 1.0366959621984775, 'alpha': 0.00388738259459602}. Best is trial 4 with value: 12.057041511757687.
# [I 2023-03-13 12:21:31,276] Trial 6 finished with value: 12.42969061027389 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 10001, 'learning_rate': 0.008, 'max_depth': 9, 'subsample': 0.6, 'colsample_bytree': 1.0, 'lambda': 0.021204812216517432, 'alpha': 0.002219094208035662}. Best is trial 4 with value: 12.057041511757687.
# [I 2023-03-13 12:22:42,089] Trial 7 finished with value: 12.07505746424985 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 13377, 'learning_rate': 0.032, 'max_depth': 4, 'subsample': 0.5, 'colsample_bytree': 0.8, 'lambda': 1.0962246826149804, 'alpha': 0.004386828492613278}. Best is trial 4 with value: 12.057041511757687.
# [I 2023-03-13 12:25:40,174] Trial 8 finished with value: 12.569473460387512 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 8568, 'learning_rate': 0.044, 'max_depth': 10, 'subsample': 0.6, 'colsample_bytree': 0.8, 'lambda': 0.028037091920107872, 'alpha': 0.04444514781725362}. Best is trial 4 with value: 12.057041511757687.
# [I 2023-03-13 12:27:54,716] Trial 9 finished with value: 12.264693431961199 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 13949, 'learning_rate': 0.025, 'max_depth': 7, 'subsample': 0.7, 'colsample_bytree': 0.9, 'lambda': 0.0038593829258409896, 'alpha': 1.993464022946902}. Best is trial 4 with value: 12.057041511757687.
# [I 2023-03-13 12:29:14,746] Trial 10 finished with value: 12.156317475192374 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 11869, 'learning_rate': 0.048999999999999995, 'max_depth': 6, 'subsample': 0.8, 'colsample_bytree': 0.5, 'lambda': 4.580255914115059, 'alpha': 0.0010587974460486047}. Best is trial 4 with value: 12.057041511757687.
# [I 2023-03-13 12:30:27,909] Trial 11 finished with value: 12.054864922047724 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 11402, 'learning_rate': 0.024, 'max_depth': 3, 'subsample': 0.5, 'colsample_bytree': 1.0, 'lambda': 2.6389833230296977, 'alpha': 0.010534721873959924}. Best is trial 11 with value: 12.054864922047724.
# [I 2023-03-13 12:31:44,421] Trial 12 finished with value: 12.06473702821237 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 11870, 'learning_rate': 0.018000000000000002, 'max_depth': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'lambda': 1.1915731403564005, 'alpha': 0.008744113421378532}. Best is trial 11 with value: 12.054864922047724.
# [I 2023-03-13 12:32:46,767] Trial 13 finished with value: 12.074803387201742 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 8490, 'learning_rate': 0.021, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.6, 'lambda': 0.21485595658897572, 'alpha': 0.01615250932978458}. Best is trial 11 with value: 12.054864922047724.
# [I 2023-03-13 12:34:34,442] Trial 14 finished with value: 12.136226350235813 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 14943, 'learning_rate': 0.016, 'max_depth': 6, 'subsample': 0.5, 'colsample_bytree': 0.7, 'lambda': 2.7892893448400025, 'alpha': 0.01097271577374559}. Best is trial 11 with value: 12.054864922047724.
# [I 2023-03-13 12:35:33,359] Trial 15 finished with value: 12.063870183152815 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 5163, 'learning_rate': 0.031000000000000003, 'max_depth': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'lambda': 0.5185352840244476, 'alpha': 0.13647975699445314}. Best is trial 11 with value: 12.054864922047724.
# [I 2023-03-13 12:37:09,186] Trial 16 finished with value: 12.131336376041466 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 11666, 'learning_rate': 0.024, 'max_depth': 5, 'subsample': 0.8, 'colsample_bytree': 0.9, 'lambda': 1.9412580988011765, 'alpha': 0.0013990971902977075}. Best is trial 11 with value: 12.054864922047724.
# [I 2023-03-13 12:38:19,701] Trial 17 finished with value: 12.12590140207464 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 10675, 'learning_rate': 0.038, 'max_depth': 5, 'subsample': 0.7, 'colsample_bytree': 0.5, 'lambda': 0.5539180321223541, 'alpha': 0.005015839356864559}. Best is trial 11 with value: 12.054864922047724.
# [I 2023-03-13 12:39:29,137] Trial 18 finished with value: 12.052562195985486 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 8631, 'learning_rate': 0.030000000000000002, 'max_depth': 3, 'subsample': 0.5, 'colsample_bytree': 1.0, 'lambda': 2.1859900049479357, 'alpha': 0.10998437511715273}. Best is trial 18 with value: 12.052562195985486.
# [I 2023-03-13 12:42:04,809] Trial 19 finished with value: 12.24154879136919 and parameters: {'objective': 'reg:squarederror', 'random_state': 42, 'n_estimators': 8654, 'learning_rate': 0.014000000000000002, 'max_depth': 7, 'subsample': 0.6, 'colsample_bytree': 1.0, 'lambda': 0.16582403526128825, 'alpha': 0.13546126915548498}. Best is trial 18 with value: 12.052562195985486.

# %%
xgb_params = study.best_params

# %%
xgb_params
# Out:
# {'objective': 'reg:squarederror',
#  'random_state': 42,
#  'n_estimators': 8631,
#  'learning_rate': 0.030000000000000002,
#  'max_depth': 3,
#  'subsample': 0.5,
#  'colsample_bytree': 1.0,
#  'lambda': 2.1859900049479357,
#  'alpha': 0.10998437511715273}

# %%
def HPO_objective(trial : Trial, X, y) :
    param = {
        "eval_metric": trial.suggest_categorical("eval_metric", ['RMSE']),
        'iterations':trial.suggest_int("iterations", 4000, 15000), 
        'od_wait':trial.suggest_int('od_wait', 500, 2300), 
        'learning_rate' : trial.suggest_uniform('learning_rate', 0.005, 0.05), 
        'reg_lambda': trial.suggest_uniform('reg_lambda', 1e-5, 100), 
        'subsample': trial.suggest_uniform('subsample', 0.5, 1), 
        'random_strength': trial.suggest_uniform('random_strength', 10, 50), 
        'depth': trial.suggest_int('depth', 3, 10), 
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 30), 
        'leaf_estimation_iterations': trial.suggest_int('leaf_estimation_iterations', 1, 15), 
        'bagging_temperature' :trial.suggest_loguniform('bagging_temperature', 0.01, 100.00), 
        'colsample_bylevel':trial.suggest_float('colsample_bylevel', 0.4, 1.0),
        "random_state": trial.suggest_categorical("random_state", [42]),
        "use_best_model": trial.suggest_categorical("use_best_model", [True])
    }
    
    model_rmse = 0
    
    for i, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
        tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
        val_x, val_y = X.iloc[val_idx], y.iloc[val_idx]

        model = CatBoostRegressor(**param)
        model.fit(tr_x, tr_y, eval_set = [(tr_x, tr_y), (val_x, val_y)], early_stopping_rounds = 1500, verbose = 0)

        val_pred = model.predict(val_x)
        fold_rmse = mean_squared_error(val_y, val_pred) ** 0.5
        model_rmse += fold_rmse / kf.n_splits
    return model_rmse

# %%
study = optuna.create_study(direction = 'minimize', sampler = TPESampler())
# Out:
# [I 2023-03-13 12:46:35,875] A new study created in memory with name: no-name-dc2c6b3a-72b0-40d1-b5e4-b51776aa37d1

# %%
study.optimize(lambda trial : HPO_objective(trial, X, y), n_trials = 20)
# Out:
# [I 2023-03-13 12:48:40,465] Trial 0 finished with value: 12.116192896672505 and parameters: {'eval_metric': 'RMSE', 'iterations': 4425, 'od_wait': 872, 'learning_rate': 0.03643834001654684, 'reg_lambda': 59.892709500499286, 'subsample': 0.6736922978396944, 'random_strength': 18.931689229746556, 'depth': 8, 'min_data_in_leaf': 21, 'leaf_estimation_iterations': 6, 'bagging_temperature': 1.7813426068014704, 'colsample_bylevel': 0.4340320345631101, 'random_state': 42, 'use_best_model': True}. Best is trial 0 with value: 12.116192896672505.
# [I 2023-03-13 12:52:10,300] Trial 1 finished with value: 12.081676180201528 and parameters: {'eval_metric': 'RMSE', 'iterations': 8278, 'od_wait': 1544, 'learning_rate': 0.022494137713091278, 'reg_lambda': 82.70905834942405, 'subsample': 0.6542155829378076, 'random_strength': 31.3798497056591, 'depth': 8, 'min_data_in_leaf': 6, 'leaf_estimation_iterations': 2, 'bagging_temperature': 2.633047873815998, 'colsample_bylevel': 0.9077821335256526, 'random_state': 42, 'use_best_model': True}. Best is trial 1 with value: 12.081676180201528.
# [I 2023-03-13 12:54:06,385] Trial 2 finished with value: 12.093073660913678 and parameters: {'eval_metric': 'RMSE', 'iterations': 7743, 'od_wait': 654, 'learning_rate': 0.03598637451911433, 'reg_lambda': 75.85227557485057, 'subsample': 0.9843835704411175, 'random_strength': 20.117028711131105, 'depth': 7, 'min_data_in_leaf': 23, 'leaf_estimation_iterations': 4, 'bagging_temperature': 3.0228681634059815, 'colsample_bylevel': 0.8324908821594303, 'random_state': 42, 'use_best_model': True}. Best is trial 1 with value: 12.081676180201528.
# [I 2023-03-13 13:00:16,114] Trial 3 finished with value: 12.17073977344821 and parameters: {'eval_metric': 'RMSE', 'iterations': 7093, 'od_wait': 625, 'learning_rate': 0.028044898833819974, 'reg_lambda': 9.814748164166767, 'subsample': 0.928740373748159, 'random_strength': 21.504154181881248, 'depth': 10, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 14, 'bagging_temperature': 0.04025072058115199, 'colsample_bylevel': 0.7199265554605198, 'random_state': 42, 'use_best_model': True}. Best is trial 1 with value: 12.081676180201528.
# [I 2023-03-13 13:05:11,739] Trial 4 finished with value: 12.11001222573806 and parameters: {'eval_metric': 'RMSE', 'iterations': 14564, 'od_wait': 947, 'learning_rate': 0.035357274436822204, 'reg_lambda': 87.15700032923125, 'subsample': 0.7160087265320859, 'random_strength': 12.342928853147907, 'depth': 9, 'min_data_in_leaf': 27, 'leaf_estimation_iterations': 15, 'bagging_temperature': 1.298661538188024, 'colsample_bylevel': 0.977869724644517, 'random_state': 42, 'use_best_model': True}. Best is trial 1 with value: 12.081676180201528.
# [I 2023-03-13 13:07:24,655] Trial 5 finished with value: 12.08476957777816 and parameters: {'eval_metric': 'RMSE', 'iterations': 14546, 'od_wait': 2000, 'learning_rate': 0.022134218833731328, 'reg_lambda': 95.71268540345633, 'subsample': 0.5707783184380306, 'random_strength': 48.804482635342566, 'depth': 7, 'min_data_in_leaf': 28, 'leaf_estimation_iterations': 14, 'bagging_temperature': 3.716762907629305, 'colsample_bylevel': 0.6365157750924979, 'random_state': 42, 'use_best_model': True}. Best is trial 1 with value: 12.081676180201528.
# [I 2023-03-13 13:09:49,145] Trial 6 finished with value: 12.071412126088891 and parameters: {'eval_metric': 'RMSE', 'iterations': 10119, 'od_wait': 1430, 'learning_rate': 0.011655119330137506, 'reg_lambda': 86.29959066316768, 'subsample': 0.6443801083628768, 'random_strength': 18.361669169740576, 'depth': 6, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 11, 'bagging_temperature': 1.4130487019774725, 'colsample_bylevel': 0.9324087140648986, 'random_state': 42, 'use_best_model': True}. Best is trial 6 with value: 12.071412126088891.
# [I 2023-03-13 13:11:29,711] Trial 7 finished with value: 12.072074590971537 and parameters: {'eval_metric': 'RMSE', 'iterations': 13890, 'od_wait': 1072, 'learning_rate': 0.011953679758772763, 'reg_lambda': 54.63315707030386, 'subsample': 0.710599133821836, 'random_strength': 30.508649425125864, 'depth': 3, 'min_data_in_leaf': 18, 'leaf_estimation_iterations': 3, 'bagging_temperature': 0.5539931541141595, 'colsample_bylevel': 0.6889873577362793, 'random_state': 42, 'use_best_model': True}. Best is trial 6 with value: 12.071412126088891.
# [I 2023-03-13 13:16:40,270] Trial 8 finished with value: 12.148727156832642 and parameters: {'eval_metric': 'RMSE', 'iterations': 4434, 'od_wait': 563, 'learning_rate': 0.019748815895119558, 'reg_lambda': 43.949776382025675, 'subsample': 0.6351888294414418, 'random_strength': 39.92260878969829, 'depth': 9, 'min_data_in_leaf': 11, 'leaf_estimation_iterations': 7, 'bagging_temperature': 2.0380593880979925, 'colsample_bylevel': 0.5141698440182847, 'random_state': 42, 'use_best_model': True}. Best is trial 6 with value: 12.071412126088891.
# [I 2023-03-13 13:19:10,294] Trial 9 finished with value: 12.086176096884177 and parameters: {'eval_metric': 'RMSE', 'iterations': 14321, 'od_wait': 1520, 'learning_rate': 0.03290732094633831, 'reg_lambda': 60.335764715351196, 'subsample': 0.6802573456545925, 'random_strength': 32.35857667631332, 'depth': 8, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 1, 'bagging_temperature': 0.12966748338188874, 'colsample_bylevel': 0.5549652183767916, 'random_state': 42, 'use_best_model': True}. Best is trial 6 with value: 12.071412126088891.
# [I 2023-03-13 13:20:18,980] Trial 10 finished with value: 12.061992393720775 and parameters: {'eval_metric': 'RMSE', 'iterations': 11292, 'od_wait': 2281, 'learning_rate': 0.04842179089964376, 'reg_lambda': 99.75744223746445, 'subsample': 0.5457367943730621, 'random_strength': 10.971040858034776, 'depth': 4, 'min_data_in_leaf': 1, 'leaf_estimation_iterations': 11, 'bagging_temperature': 65.08497846061059, 'colsample_bylevel': 0.9936192687795804, 'random_state': 42, 'use_best_model': True}. Best is trial 10 with value: 12.061992393720775.
# [I 2023-03-13 13:21:32,996] Trial 11 finished with value: 12.059038987846252 and parameters: {'eval_metric': 'RMSE', 'iterations': 11345, 'od_wait': 2254, 'learning_rate': 0.044151759481315334, 'reg_lambda': 99.66350736727402, 'subsample': 0.5045597205367082, 'random_strength': 10.328390798637777, 'depth': 4, 'min_data_in_leaf': 1, 'leaf_estimation_iterations': 11, 'bagging_temperature': 65.76530012019344, 'colsample_bylevel': 0.9979538381243023, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.
# [I 2023-03-13 13:22:45,749] Trial 12 finished with value: 12.064699741639723 and parameters: {'eval_metric': 'RMSE', 'iterations': 12063, 'od_wait': 2184, 'learning_rate': 0.04853853699664143, 'reg_lambda': 98.35804009059281, 'subsample': 0.5025533148917083, 'random_strength': 11.39132417199086, 'depth': 4, 'min_data_in_leaf': 2, 'leaf_estimation_iterations': 10, 'bagging_temperature': 99.65655850110362, 'colsample_bylevel': 0.9736552316163326, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.
# [I 2023-03-13 13:24:07,291] Trial 13 finished with value: 12.06021719008507 and parameters: {'eval_metric': 'RMSE', 'iterations': 10965, 'od_wait': 1880, 'learning_rate': 0.049108436877647786, 'reg_lambda': 97.85837841257133, 'subsample': 0.5254001595409006, 'random_strength': 10.345937267737911, 'depth': 5, 'min_data_in_leaf': 2, 'leaf_estimation_iterations': 11, 'bagging_temperature': 98.5326180188494, 'colsample_bylevel': 0.8222697136047236, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.
# [I 2023-03-13 13:25:25,402] Trial 14 finished with value: 12.07056521020865 and parameters: {'eval_metric': 'RMSE', 'iterations': 12236, 'od_wait': 1900, 'learning_rate': 0.04305092164134681, 'reg_lambda': 71.61047446873751, 'subsample': 0.5010984973333201, 'random_strength': 24.953620047984916, 'depth': 5, 'min_data_in_leaf': 5, 'leaf_estimation_iterations': 9, 'bagging_temperature': 21.577189266195056, 'colsample_bylevel': 0.8498320550501147, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.
# [I 2023-03-13 13:26:46,665] Trial 15 finished with value: 12.074372428979904 and parameters: {'eval_metric': 'RMSE', 'iterations': 9924, 'od_wait': 1745, 'learning_rate': 0.04256830164991127, 'reg_lambda': 73.36285426971551, 'subsample': 0.5882180257175932, 'random_strength': 14.680200052349214, 'depth': 5, 'min_data_in_leaf': 6, 'leaf_estimation_iterations': 12, 'bagging_temperature': 16.78964248780969, 'colsample_bylevel': 0.8138733658078938, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.
# [I 2023-03-13 13:27:49,590] Trial 16 finished with value: 12.066627778043122 and parameters: {'eval_metric': 'RMSE', 'iterations': 11236, 'od_wait': 2042, 'learning_rate': 0.04982280722556496, 'reg_lambda': 98.24897524049113, 'subsample': 0.5815456645987293, 'random_strength': 10.445363470017448, 'depth': 3, 'min_data_in_leaf': 3, 'leaf_estimation_iterations': 8, 'bagging_temperature': 24.782889053539986, 'colsample_bylevel': 0.8925896059125323, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.
# [I 2023-03-13 13:29:13,338] Trial 17 finished with value: 12.08420504533069 and parameters: {'eval_metric': 'RMSE', 'iterations': 9032, 'od_wait': 1738, 'learning_rate': 0.042593589417442165, 'reg_lambda': 84.25514617315794, 'subsample': 0.772737181207268, 'random_strength': 15.900906254855553, 'depth': 5, 'min_data_in_leaf': 9, 'leaf_estimation_iterations': 13, 'bagging_temperature': 8.07972472112175, 'colsample_bylevel': 0.766435669168797, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.
# [I 2023-03-13 13:30:15,652] Trial 18 finished with value: 12.059235453512699 and parameters: {'eval_metric': 'RMSE', 'iterations': 13033, 'od_wait': 1785, 'learning_rate': 0.04477391599257586, 'reg_lambda': 36.315009445034896, 'subsample': 0.5068571175715659, 'random_strength': 23.527028237312873, 'depth': 4, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 5, 'bagging_temperature': 51.55225543578351, 'colsample_bylevel': 0.8773686874527196, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.
# [I 2023-03-13 13:31:18,714] Trial 19 finished with value: 12.07702064459484 and parameters: {'eval_metric': 'RMSE', 'iterations': 12712, 'od_wait': 1268, 'learning_rate': 0.040320975633470466, 'reg_lambda': 41.1021534880255, 'subsample': 0.6012697351499747, 'random_strength': 24.475064242273046, 'depth': 4, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 5, 'bagging_temperature': 41.45663259804757, 'colsample_bylevel': 0.9209723442840274, 'random_state': 42, 'use_best_model': True}. Best is trial 11 with value: 12.059038987846252.

# %%
cb_params = study.best_params

# %%
cb_params
# Out:
# {'eval_metric': 'RMSE',
#  'iterations': 11345,
#  'od_wait': 2254,
#  'learning_rate': 0.044151759481315334,
#  'reg_lambda': 99.66350736727402,
#  'subsample': 0.5045597205367082,
#  'random_strength': 10.328390798637777,
#  'depth': 4,
#  'min_data_in_leaf': 1,
#  'leaf_estimation_iterations': 11,
#  'bagging_temperature': 65.76530012019344,
#  'colsample_bylevel': 0.9979538381243023,
#  'random_state': 42,
#  'use_best_model': True}

# %%
rmse_ens = []

pred_1 = np.zeros(target.shape[0])
pred_2 = np.zeros(target.shape[0])
pred_3 = np.zeros(target.shape[0])

for i, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
    tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
    val_x, val_y = X.iloc[val_idx], y.iloc[val_idx]
    
    # XGBoost
    model_xgb = XGBRegressor(**xgb_params)
    model_xgb.fit(tr_x, tr_y, eval_set = [(val_x, val_y)], early_stopping_rounds = 1000, verbose = False)
    val_pred_xgb = model_xgb.predict(val_x)
    pred_1 += model_xgb.predict(target) / kf.n_splits
    
    # CatBoost
    model_cat = CatBoostRegressor(**cb_params)
    model_cat.fit(tr_x, tr_y, eval_set = [(val_x, val_y)], early_stopping_rounds = 1000, verbose = False) 
    val_pred_cat = model_cat.predict(val_x)
    pred_2 += model_cat.predict(target) / kf.n_splits

    # LGBM
    model_lgbm = LGBMRegressor(**lgbm_params)
    model_lgbm.fit(tr_x, tr_y, eval_set = [(val_x, val_y)], early_stopping_rounds = 1000, verbose = 0)
    val_pred_lgbm = model_lgbm.predict(val_x)
    pred_3 += model_lgbm.predict(target) / kf.n_splits

    ens_pred = val_pred_xgb * 0.01 + val_pred_lgbm * 0.19 + val_pred_cat * 0.8
    rmse_ens.append(mean_squared_error(val_y, ens_pred, squared = False))
 
    print(f"fold : {i + 1} RMSE of Ensemble : {rmse_ens[i]}")
# Out:
# fold : 1 RMSE of Ensemble : 11.743342281095954
# fold : 2 RMSE of Ensemble : 11.69605714694925
# fold : 3 RMSE of Ensemble : 12.31560606057687
# fold : 4 RMSE of Ensemble : 11.62028339584501
# fold : 5 RMSE of Ensemble : 12.64158896338211
# fold : 6 RMSE of Ensemble : 11.679223124183142
# fold : 7 RMSE of Ensemble : 12.057749756536067
# fold : 8 RMSE of Ensemble : 12.022288698483699
# fold : 9 RMSE of Ensemble : 12.599534932059605
# fold : 10 RMSE of Ensemble : 12.10835463472983

# %%
print(f'\n{np.mean(rmse_ens)}')
# Out:
# 12.048402899384154

# %% [markdown]
# best = 12.043611527687109

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
submission['Strength'] = pred_2 * 0.8 + pred_1 * 0.01 + pred_3 * 0.19

# %%
submission.to_csv("ensemble.csv", index = False)

# %% [markdown]
# ***

# %%
pred_xgb=[]  
pred_cat=[]
pred_lgbm = []

for i, (tr_idx, val_idx) in enumerate(kf.split(X, y)) :
    tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
    val_x, val_y = X.iloc[val_idx], y.iloc[val_idx]
    
    # XGBoost
    model_xgb = XGBRegressor(random_state = 42, max_depth = 4, learning_rate = 0.02, n_estimators = 10000, objective = 'reg:squarederror')
    model_xgb.fit(tr_x, tr_y, eval_set = [(val_x, val_y)], early_stopping_rounds = 1000, verbose = False)
    val_pred_xgb = model_xgb.predict(val_x)

    # CatBoost
    model_cat = CatBoostRegressor(random_state = 42, max_depth = 4, learning_rate = 0.02, n_estimators = 10000, use_best_model = True, eval_metric = 'RMSE')
    model_cat.fit(tr_x, tr_y, eval_set = [(val_x, val_y)], early_stopping_rounds = 1000, verbose = False) 
    val_pred_cat = model_cat.predict(val_x)
    
    # LGBM
    model_lgbm = LGBMRegressor(random_state = 42, max_depth = 5, learning_rate = 0.02, n_estimators = 10000, objective = 'rmse')
    model_lgbm.fit(tr_x, tr_y, eval_set = [(val_x, val_y)], early_stopping_rounds = 1000, verbose = 0)
    val_pred_lgbm = model_lgbm.predict(val_x)
    
    pred_xgb.append(val_pred_xgb)
    pred_cat.append(val_pred_cat)
    pred_lgbm.append(val_pred_lgbm)

# %%
ens1_rmse = []
ens2_rmse = []
ens3_rmse = []
ens4_rmse = []

for i in range(10) :

  ens1 = pred_xgb[i] * 0.15 + pred_lgbm[i] * 0.05 + pred_cat[i] * 0.8
  ens2 = pred_xgb[i] * 0.1 + pred_lgbm[i] * 0.1 + pred_cat[i] * 0.8
  ens3 = pred_xgb[i] * 0.05 + pred_lgbm[i] * 0.15 + pred_cat[i] * 0.8
  ens4 = pred_xgb[i] * 0.01 + pred_lgbm[i] * 0.19 + pred_cat[i] * 0.8

  rmse1 = mean_squared_error(val_ys[i], ens1, squared = False)
  rmse2 = mean_squared_error(val_ys[i], ens2, squared = False)
  rmse3 = mean_squared_error(val_ys[i], ens3, squared = False)
  rmse4 = mean_squared_error(val_ys[i], ens4, squared = False)

  ens1_rmse.append(rmse1)
  ens2_rmse.append(rmse2)
  ens3_rmse.append(rmse3)
  ens4_rmse.append(rmse4)
print(np.mean(ens1_rmse), np.mean(ens2_rmse), np.mean(ens3_rmse), np.mean(ens4_rmse))
# Out:
# 12.046895611857169 12.045387372625246 12.044251724220057 12.043611527687109
